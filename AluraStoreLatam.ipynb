# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import matplotlib.pyplot as plt

# Ingreso total por tienda
ingreso_tienda_1 = tienda['Precio'].sum()
ingreso_tienda_2 = tienda2['Precio'].sum()
ingreso_tienda_3 = tienda3['Precio'].sum()
ingreso_tienda_4 = tienda4['Precio'].sum()

# Resultados
print(f'Ingreso total tienda 1: ${ingreso_tienda_1}')
print(f'Ingreso total tienda 2: ${ingreso_tienda_2}')
print(f'Ingreso total tienda 3: ${ingreso_tienda_3}')
print(f'Ingreso total tienda 4: ${ingreso_tienda_4}')
# Out:
# Ingreso total tienda 1: $1150880400.0
# Ingreso total tienda 2: $1116343500.0
# Ingreso total tienda 3: $1098019600.0
# Ingreso total tienda 4: $1038375700.0

# %%
# Gráfico de barras
plt.figure(figsize=(8, 5))

# Lista con los nombres de las tiendas para el eje x
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Lista con los ingresos totales de cada tienda
ingresos = [ingreso_tienda_1, ingreso_tienda_2, ingreso_tienda_3, ingreso_tienda_4]

# Colores
colores = ['#374999', '#b51010', '#08c0af', '#d85b13']

# Nombres e ingresos en plt.bar
barras = plt.bar(nombres_tiendas, ingresos, color=colores)
plt.title('Ingreso Total por Tienda')
plt.xlabel('Tienda')

plt.ylabel('Ingreso ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Etiquetas de valor encima de cada barra
for barra in barras:
    yval = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, yval + 10, f'${yval:,.0f}',
             ha='center', va='bottom', fontsize=9, fontweight='medium')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Ventas por categoría
ventas_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)
ventas_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Producto'].count().sort_values(ascending=False)

# Resultados
print("\nVentas por categoría - Tienda 1:")
print(ventas_categoria_tienda1)

print("\nVentas por categoría - Tienda 2:")
print(ventas_categoria_tienda2)

print("\nVentas por categoría - Tienda 3:")
print(ventas_categoria_tienda3)

print("\nVentas por categoría - Tienda 4:")
print(ventas_categoria_tienda4)
# Out:
# Ventas por categoría - Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Producto, dtype: int64
#
# Ventas por categoría - Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Producto, dtype: int64
#
# Ventas por categoría - Tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %%
# Productos por categoría
cat1 = tienda.groupby('Categoría del Producto')['Producto'].count()
cat2 = tienda2.groupby('Categoría del Producto')['Producto'].count()
cat3 = tienda3.groupby('Categoría del Producto')['Producto'].count()
cat4 = tienda4.groupby('Categoría del Producto')['Producto'].count()

# Obtener todas las categorías únicas
todas_categorias = sorted(set(cat1.index) | set(cat2.index) | set(cat3.index) | set(cat4.index))

# Asignar colores consistentes por categoría
import matplotlib.colors as mcolors
color_list = list(mcolors.TABLEAU_COLORS.values())
colores_categoria = {cat: color_list[i % len(color_list)] for i, cat in enumerate(todas_categorias)}

# Función para graficar pie chart por tienda
def graficar_torta(datos, titulo):
    # Reordenar los datos para que incluyan todas las categorías
    datos_completos = [datos.get(cat, 0) for cat in todas_categorias]
    colores = [colores_categoria[cat] for cat in todas_categorias]

    plt.figure(figsize=(6, 6))
    plt.pie(
        datos_completos,
        labels=todas_categorias,
        colors=colores,
        autopct='%1.1f%%',
        startangle=140
    )
    plt.title(titulo)
    plt.axis('equal')  # Igual proporción
    plt.tight_layout()
    plt.show()

# Crear gráficos
graficar_torta(cat1, 'Tienda 1 - Ventas por Categoría')
graficar_torta(cat2, 'Tienda 2 - Ventas por Categoría')
graficar_torta(cat3, 'Tienda 3 - Ventas por Categoría')
graficar_torta(cat4, 'Tienda 4 - Ventas por Categoría')

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular el promedio de calificaciones por tienda
promedio_1 = tienda['Calificación'].mean()
promedio_2 = tienda2['Calificación'].mean()
promedio_3 = tienda3['Calificación'].mean()
promedio_4 = tienda4['Calificación'].mean()

# Mostrar resultados
print(f'⭐ Promedio calificación Tienda 1: {promedio_1:.2f}')
print(f'⭐ Promedio calificación Tienda 2: {promedio_2:.2f}')
print(f'⭐ Promedio calificación Tienda 3: {promedio_3:.2f}')
print(f'⭐ Promedio calificación Tienda 4: {promedio_4:.2f}')
# Out:
# ⭐ Promedio calificación Tienda 1: 3.98
# ⭐ Promedio calificación Tienda 2: 4.04
# ⭐ Promedio calificación Tienda 3: 4.05
# ⭐ Promedio calificación Tienda 4: 4.00

# %%
# Calcular el promedio de calificaciones por tienda
promedio_1 = tienda['Calificación'].mean()
promedio_2 = tienda2['Calificación'].mean()
promedio_3 = tienda3['Calificación'].mean()
promedio_4 = tienda4['Calificación'].mean()

# Nombres de las tiendas
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Lista con los promedios de calificación
promedios = [promedio_1, promedio_2, promedio_3, promedio_4]

# Gráfico de barras
plt.figure(figsize=(8, 6))
bars = plt.bar(tiendas, promedios, color='skyblue')

# Etiquetas de valor sobre cada barra
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, f'{yval:.2f}', ha='center', va='bottom')

# Estética del gráfico
plt.title('Promedio de Calificación por Tienda')
plt.ylabel('Promedio de Calificación')
plt.ylim(0, 5)  # Asumiendo calificación de 0 a 5
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar gráfico
plt.tight_layout()
plt.show()

# %%
# Crear una figura con 4 subgráficos (uno por tienda)
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Distribución de calificaciones por tienda', fontsize=16)

# Datos para graficar
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
axes = axs.flatten()

# Crear histogramas
for i in range(4):
    axes[i].hist(tiendas[i]['Calificación'], bins=range(1, 7), edgecolor='black', color='skyblue', align='left')
    axes[i].set_title(nombres[i])
    axes[i].set_xlabel('Calificación')
    axes[i].set_ylabel('Frecuencia')
    axes[i].set_xticks(range(1, 6))

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def listar_productos_mas_vendidos(df, nombre_tienda):
    print(f'\n📦 Productos más vendidos - {nombre_tienda}')
    ventas = df['Producto'].value_counts()
    print(ventas.to_string())

# Ejecutar para cada tienda
listar_productos_mas_vendidos(tienda, "Tienda 1")
listar_productos_mas_vendidos(tienda2, "Tienda 2")
listar_productos_mas_vendidos(tienda3, "Tienda 3")
listar_productos_mas_vendidos(tienda4, "Tienda 4")
# Out:
# 📦 Productos más vendidos - Tienda 1
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# ...

# %%
import matplotlib.pyplot as plt

# Tiendas
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Crear figura
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Top 10 productos más vendidos por tienda', fontsize=18)
axs = axs.flatten()

# Gráfico para cada tienda
for i, df in enumerate(tiendas):
    top_productos = df['Producto'].value_counts().head(10)
    axs[i].barh(top_productos.index[::-1], top_productos.values[::-1], color='skyblue')
    axs[i].set_title(nombres_tiendas[i])
    axs[i].set_xlabel('Cantidad Vendida')
    axs[i].set_ylabel('Producto')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Conteo de productos por tienda
ventas_tienda_1 = tienda['Producto'].value_counts()
ventas_tienda_2 = tienda2['Producto'].value_counts()
ventas_tienda_3 = tienda3['Producto'].value_counts()
ventas_tienda_4 = tienda4['Producto'].value_counts()

# Combinar datos
df_heatmap = pd.concat([ventas_tienda_1, ventas_tienda_2, ventas_tienda_3, ventas_tienda_4], axis=1)
df_heatmap.columns = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
df_heatmap.fillna(0, inplace=True)  # Rellenar NaN con 0
df_heatmap = df_heatmap.astype(int)

# (Opcional) Filtrar los 20 productos más vendidos en total
top_productos = df_heatmap.sum(axis=1).sort_values(ascending=False).head(20).index
df_top = df_heatmap.loc[top_productos]

# Graficar Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_top, annot=True, fmt='d', cmap='YlGnBu', linewidths=0.5)
plt.title('Ventas de productos por tienda')
plt.xlabel('Tienda')
plt.ylabel('Producto')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Cálculo promedio del costo de envío por tienda
promedio_envio_tienda_1 = round(tienda['Costo de envío'].mean())
promedio_envio_tienda_2 = round(tienda2['Costo de envío'].mean())
promedio_envio_tienda_3 = round(tienda3['Costo de envío'].mean())
promedio_envio_tienda_4 = round(tienda4['Costo de envío'].mean())

# Resultados
print(f'Promedio envío Tienda 1: ${promedio_envio_tienda_1}')
print(f'Promedio envío Tienda 2: ${promedio_envio_tienda_2}')
print(f'Promedio envío Tienda 3: ${promedio_envio_tienda_3}')
print(f'Promedio envío Tienda 4: ${promedio_envio_tienda_4}')
# Out:
# Promedio envío Tienda 1: $26019
# Promedio envío Tienda 2: $25216
# Promedio envío Tienda 3: $24806
# Promedio envío Tienda 4: $23459

# %%
import matplotlib.pyplot as plt

# Calculo promedio costo de envío
promedio_envio_t1 = round(tienda['Costo de envío'].mean())
promedio_envio_t2 = round(tienda2['Costo de envío'].mean())
promedio_envio_t3 = round(tienda3['Costo de envío'].mean())
promedio_envio_t4 = round(tienda4['Costo de envío'].mean())

# Datos para el gráfico
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
costos_envio = [promedio_envio_t1, promedio_envio_t2, promedio_envio_t3, promedio_envio_t4]
colores = ['#4CAF50', '#2196F3', '#FFC107', '#E91E63']

# Crear gráfico de barras
plt.figure(figsize=(8, 6))
barras = plt.bar(tiendas, costos_envio, color=colores)

# Agregar etiquetas de valor sobre cada barra
for barra in barras:
    height = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2, height + 1, f"${height}", ha='center', va='bottom', fontsize=10)

# Personalización
plt.title('Promedio del costo de envío por tienda')
plt.ylabel('Costo promedio ($)')
plt.ylim(0, max(costos_envio) + 10)

# Mostrar gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Ingreso total por tienda
ingreso_tienda_1 = tienda['Precio'].sum()
ingreso_tienda_2 = tienda2['Precio'].sum()
ingreso_tienda_3 = tienda3['Precio'].sum()
ingreso_tienda_4 = tienda4['Precio'].sum()

# Costo de envío por tienda

costos_envio_tienda1 = tienda['Costo de envío'].sum()
costos_envio_tienda2 = tienda2['Costo de envío'].sum()
costos_envio_tienda3 = tienda3['Costo de envío'].sum()
costos_envio_tienda4 = tienda4['Costo de envío'].sum()

# Ventas Netas
ventas_netas_tienda_1 = ingreso_tienda_1 - costos_envio_tienda1
ventas_netas_tienda_2 = ingreso_tienda_2 - costos_envio_tienda2
ventas_netas_tienda_3 = ingreso_tienda_3 - costos_envio_tienda3
ventas_netas_tienda_4 = ingreso_tienda_4 - costos_envio_tienda4

# Mostrar el resultado
print(f"Ventas netas: ${ventas_netas_tienda_1: }")
print(f"Ventas netas: ${ventas_netas_tienda_2: }")
print(f"Ventas netas: ${ventas_netas_tienda_3: }")
print(f"Ventas netas: ${ventas_netas_tienda_4: }")
# Out:
# Ventas netas: $ 1089502500.0
# Ventas netas: $ 1056858400.0
# Ventas netas: $ 1039503000.0
# Ventas netas: $ 983058300.0

# %%
# Crear figura
plt.figure(figsize=(8, 6))

# Datos para el gráfico
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas_netas = [ventas_netas_tienda_1, ventas_netas_tienda_2, ventas_netas_tienda_3, ventas_netas_tienda_4]

# Colores para las barras
colores = ['#FF6347', '#4682B4', '#32CD32', '#FFD700'] # Tomate, Acero Azul, Verde Limón, Oro

# Crear gráfico de barras
barras = plt.bar(tiendas, ventas_netas, color=colores)

# Agregar etiquetas de valor sobre cada barra
for barra in barras:
    height = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2, height + (max(ventas_netas) * 0.01), f"${height:,.0f}", ha='center', va='bottom', fontsize=10, fontweight='medium')

# Personalización
plt.title('Ventas Netas por Tienda (Ingresos - Costo de Envío)')
plt.ylabel('Ventas Netas ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis de los resultados**
#
# En base al data frame entregado por cliente de analizó algunos rendimientos claves de las 4 tiendas que tiene don Juan. Los resultados fueron los siguientes:
#
# **Ingresos por tienda:** Analizadas las ventas de las 4 tiendas, la tienda 1 es la de mayor ingresos por venta con un total de $1.089.502.500. Por el contrario, la tienda con menores ventas es la tienda 4 con un total de $983.058.300.
#
# Ventas por categoría:
#
# - En general las categorías más importante en ventas en todas las tiendas son las de **muebles** y **electrónicos**,
